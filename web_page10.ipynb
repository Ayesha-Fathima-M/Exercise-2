# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha-Fathima-M/Exercise-2/blob/main/web_page10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Specify the URL of the web page you want to import
url = "https://timesofindia.indiatimes.com/?from=mdr"

# Send an HTTP GET request to fetch the web page content
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Print the HTML content of the web page
    print(response.text)
else:
    print("Failed to fetch the web page.")
# Out:
# <!doctype html><html class="no-js" lang="en"><head><meta charSet="utf-8"/><meta http-equiv="x-ua-compatible" content="ie=edge"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/><title>News: US News, Top News in India, US election news, Business news, Sports &amp; International News | Times of India</title><meta name="description" content="Read Top News in India and around the World on Times of India. Breaking news coverage and analysis on US presidential election, politics, current affairs, business &amp; sports."/><meta name="keywords" content="News, US News, US election news, India news, English news, international news, business news, US news today, current affairs, breaking news"/><link rel="canonical" href="https://timesofindia.indiatimes.com/us"/><link rel="alternate" href="https://timesofindia.indiatimes.com/us" hrefLang="en-us"/><link rel="alternate" href="https://timesofindia.indiatimes.com" hrefLang="en-IN"/><link rel="alternate" href="h
# ...

# %%
pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# Specify the URL of the web page you want to import
url = "https://timesofindia.indiatimes.com/?from=mdr"

# Send an HTTP GET request to fetch the web page content
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Print the prettified HTML content (optional)
    print(soup.prettify())
else:
    print("Failed to fetch the web page.")
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <title>
#    News: US News, Top News in India, US election news, Business news, Sports &amp; International News | Times of India
#   </title>
#   <meta content="Read Top News in India and around the World on Times of India. Breaking news coverage and analysis on US presidential election, politics, current affairs, business &amp; sports." name="description"/>
#   <meta content="News, US News, US election news, India news, English news, international news, business news, US news today, current affairs, breaking news" name="keywords"/>
#   <link href="https://timesofindia.indiatimes.com/us" rel="canonical"/>
#   <link href="https://timesofindia.indiatimes.com/us" hreflang="en-us" rel="alternate"/>
# ...

# %%
# Find a specific element by tag and class
title_element = soup.find('h1', class_='title-class')
if title_element:
    print("Title:", title_element.text)

# Find all elements of a specific tag
paragraphs = soup.find_all('p')
for paragraph in paragraphs:
    print("Paragraph:", paragraph.text)
# Out:
# Paragraph: This courtroom comedy on sex education is entertaining and socially relevant.
# Paragraph: Rajnikanth is not a hero anymore; he is a superstar and this film shows him exactly as that.
# Paragraph: At heart, 'Rocky Aur Rani Kii Prem Kahaani' is an entertaining and sweet love story, with flashy and feisty characters given to us in a well-wrapped shiny package. And yet, it's all about loving your
# Paragraph: Meet cricketer Sarfaraz Khan's beautiful Kashmiri wife Romana Zahoor
# Paragraph: ​Why you should always add green chilli to food?​
# Paragraph: Adorable moments of Vijay Raghavendra with wife Spandana
# Paragraph: 7 healthy habits all individuals should adopt at 40 to live longer
# Paragraph: 13 Popular Biryanis and their calories in per serving
# Paragraph: Time travel: Oldest Mughal structures that reflect architectural brilliance
# Paragraph: 15 foods rich in antioxidants
# Paragraph: 12 vegetarian foods that can increase stamina
